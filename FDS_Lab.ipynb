# %% [markdown]
# # Fundamentals of Data Science Lab Works

# %% [markdown]
# ## Experiment 1

# %% [markdown]
# ### Write a python program to create a simple calculator which can perform basic arithmetic operations like addition, subtraction, multiplication or division depending upon the user input.

# %%
def add(num1,num2):
  return num1+num2

def subract(num1,num2):
  return num1-num2

def multiply(num1,num2):
  return num1*num2

def divide(num1,num2):
  return num1/num2
print("Please Select the operator: \n 1.Addition \n 2.Subract \n 3.Multiply \n 4.Divide")

Select=int(input("Select Operator 1,2,3,4: "))

number_1 = int(input("Enter First Number: "))
number_2 = int(input("Enter Second Number: "))

if Select==1:
  print(number_1,"+",number_2,"=",add(number_1,number_2))

elif Select==2:
  print(number_1,"-",number_2,"=",subract(number_1,number_2))

elif Select==3: 
  print(number_1,"*",number_2,"=",multiply(number_1,number_2))

elif Select==4:
  print(number_1,"/",number_2,"=",divide(number_1,number_2))

else:
  print("Invalid")
# Out:
# Please Select the operator:
#  1.Addition
#  2.Subract
#  3.Multiply
#  4.Divide
# 4 - 3 = 1

# %% [markdown]
# ## Experiment 2

# %% [markdown]
# ### Write a python program in Basic Statistics functions.

# %%
import numpy as np 
from collections import Counter 
from scipy import stats 
a= [11, 21, 34, 22, 27, 11, 23, 21]
mean = sum(a)/len(a) 
print("Mean using normal method: ")
print(mean)
#Mean using numpy method
mean = np.mean(a) 
print("Mean using Numpy: ")
print(mean)
#Median by simple Computation. 
def median(nums):
  nums.sort()
  if len(nums)%2 == 0:
    return int(nums[len(nums)//2-1]+nums[len(nums)//2])/2 
  else:
    return nums[len(nums)//2] 
    print("The median using Normal mrthod: ",median(a))
    print(median(a))
#Mode by simple Computation 
data = dict(Counter(a))
mode = [k for k, v in data.items() if v == max(list(data.values()))] 
print("The mode using normal method is: ", mode)
print(mode)
#Mode using numpy method 
print("The mode using numpy is: ")
print(stats.mode(a)[0][0])
#Quartiles by simple method 
def quartiles(nums):
  nums=sorted(nums)
  Q1 = median(nums[:len(nums)//2]) 
  Q2 = median(nums)
  if len(nums)%2 == 0:
    Q3 = median(nums[len(nums)//2:]) 
  else:
    Q3 = median(nums[len(nums)//2+1:]) 
    return Q1,Q2,Q3
def median(nums): 
  nums.sort()
  if len(nums)%2 == 0:
    return int(nums[len(nums)//2-1]+nums[len(nums)//2])/2  
  else:
    return nums[len(nums)//2] 
    print (quartiles(a))

#Standard deviation by simple computation 
n=len(a)
std=(sum(map(lambda x: (x-sum(a)/n)**2,a))/n )**0.5 
print("The standard deviation using Normal Method is: ",std)
std_n = np.std(a)
print("Standard deviation using numpy method is:",std_n)
# Out:
# Mean using normal method:
# 21.25
# Mean using Numpy:
# 21.25
# The mode using normal method is:  [11, 21]
# [11, 21]
# The mode using numpy is:
# 11
# The standard deviation using Normal Method is:  7.1545440106270926
# Standard deviation using numpy method is: 7.1545440106270926

# %% [markdown]
# ## Experiment 3

# %% [markdown]
# ### Visualization
